# %%
from dotenv import load_dotenv
load_dotenv()

from graph import build_graph
from state import TravelState


def main():
    print("=== AI Travel Agent (LangGraph Edition) ===")

    origin = input("Origin (e.g., BLR): ").strip()
    destination = input("Destination (e.g., Mumbai): ").strip()
    start_date = input("Start date (YYYY-MM-DD): ").strip()
    end_date = input("End date (YYYY-MM-DD): ").strip()

    bedrooms = int(input("Bedrooms (default 1): ") or 1)
    max_price = float(input("Max price per night (default 200): ") or 200)
    min_rating = float(input("Min rating (default 4.0): ") or 4.0)

    graph = build_graph()

    initial_state = TravelState(
        origin=origin,
        destination=destination,
        start_date=start_date,
        end_date=end_date,
        bedrooms=bedrooms,
        max_price_per_night=max_price,
        min_rating=min_rating,
    )

    final_state = graph.invoke(initial_state)

    # Normalize to dict
    if isinstance(final_state, TravelState):
        final_state = final_state.model_dump()

    weather_summary = final_state.get("weather_summary")
    recommended_hotels = final_state.get("recommended_hotels", [])
    flights = final_state.get("flights", [])

    print("\n=== WEATHER ===")
    if weather_summary:
        print(weather_summary)
    else:
        print("No weather summary available.")

    print("\n=== TOP HOTELS ===")
    if recommended_hotels:
        for h in recommended_hotels:
            name = h.get("name")
            rating = h.get("rating")
            price = h.get("price") or h.get("price_per_night")
            url = h.get("url")

            try:
                price_str = f"{float(price):.2f}" if price is not None else "N/A"
            except Exception:
                price_str = "N/A"

            print(f"- {name} — ⭐ {rating} — {price_str} per night → {url}")
    else:
        print("No hotel recommendations found.")

    print("\n=== TOP FLIGHTS ===")
    if flights:
        for f in flights:
            airline = f.get("airline")
            origin_f = f.get("origin")
            dest_f = f.get("destination")
            price = f.get("price")
            url = f.get("url")
            print(f"- {airline} {origin_f} → {dest_f} — {price} → {url}")
    else:
        print("No flight options found.")

    print("\n🎉 Done! Your LangGraph-powered travel planning run is complete.\n")


# if __name__ == "__main__":
#     main()

# %%
print("=== AI Travel Agent (LangGraph Edition) ===")

origin = 'Casablanca Morocco'
destination = "Laayoune Morocco"
start_date = '2025-12-12'
end_date = '2026-01-12'

bedrooms = 1
max_price = 200
min_rating = 4

graph = build_graph()

initial_state = TravelState(
    origin=origin,
    destination=destination,
    start_date=start_date,
    end_date=end_date,
    bedrooms=bedrooms,
    max_price_per_night=max_price,
    min_rating=min_rating,
)

final_state = graph.invoke(initial_state)

# Normalize to dict
if isinstance(final_state, TravelState):
    final_state = final_state.model_dump()

weather_summary = final_state.get("weather_summary")
recommended_hotels = final_state.get("recommended_hotels", [])
flights = final_state.get("flights", [])
# Out:
# === AI Travel Agent (LangGraph Edition) ===
#
# --- RAW LLM OUTPUT (for debugging) ---
# {
#   "accommodations": [
#     {
#       "name": "Hotel Sahara Comfort",
#       "city": "Laayoune",
#       "country": "Morocco",
#       "price": 150.0,
#       "rating": 4.2,
#       "bedrooms": 1,
#       "url": "https://hotels.example.com/sahara-comfort-laayoune"
#     },
#     {
#       "name": "Laayoune Central Inn",
#       "city": "Laayoune",
#       "country": "Morocco",
#       "price": 120.0,
#       "rating": 4.5,
#       "bedrooms": 1,
#       "url": "https://hotels.example.com/laayoune-central-inn"
#     },
#     {
#       "name": "Desert Star Hotel",
#       "city": "Laayoune",
#       "country": "Morocco",
#       "price": 180.0,
#       "rating": 4.0,
#       "bedrooms": 1,
#       "url": "https://hotels.example.com/desert-star-laayoune"
#     },
#     {
#       "name": "Oasis View Hotel",
#       "city": "Laayoune",
#       "country": "Morocco",
#       "price": 190.0,
#       "rating": 4.3,
#       "bedrooms": 1,
#       "url": "https://hotels.example.com/oasis-view-laayoune"
#     },
#     {
#       "name": "Atlantic Breeze Hotel",
#       "city": "Laayoune",
#       "country": "Morocco",
#       "price": 170.0,
#       "rating": 4.1,
#       "bedrooms": 1,
#       "url": "https://hotels.example.com/atlantic-breeze-laayoune"
#     }
#   ],
#   "flights": [
#     {
#       "airline": "Royal Air Maroc",
#       "origin": "Casablanca",
#       "destination": "Laayoune",
#       "price": 120.0,
#       "url": "https://flights.example.com/royalairmaroc-cas-laayoune"
#     },
#     {
#       "airline": "Air Arabia Maroc",
#       "origin": "Casablanca",
#       "destination": "Laayoune",
#       "price": 110.0,
#       "url": "https://flights.example.com/airarabiamaroc-cas-laayoune"
#     },
#     {
#       "airline": "Atlas Blue",
#       "origin": "Casablanca",
#       "destination": "Laayoune",
#       "price": 130.0,
#       "url": "https://flights.example.com/atlasblue-cas-laayoune"
#     }
#   ]
# }
# --- END RAW LLM OUTPUT ---
#
# ⚠️ AVIATIONSTACK_API_KEY not set; skipping real flight API.

# %%
print("\n=== WEATHER ===")
if weather_summary:
    print(weather_summary)
else:
    print("No weather summary available.")

print("\n=== TOP HOTELS ===")
if recommended_hotels:
    for h in recommended_hotels:
        name = h.get("name")
        rating = h.get("rating")
        price = h.get("price") or h.get("price_per_night")
        url = h.get("url")

        try:
            price_str = f"{float(price):.2f}" if price is not None else "N/A"
        except Exception:
            price_str = "N/A"

        print(f"- {name} — ⭐ {rating} — {price_str} per night → {url}")
else:
    print("No hotel recommendations found.")

print("\n=== TOP FLIGHTS ===")
if flights:
    for f in flights:
        airline = f.get("airline")
        origin_f = f.get("origin")
        dest_f = f.get("destination")
        price = f.get("price")
        url = f.get("url")
        print(f"- {airline} {origin_f} → {dest_f} — {price} → {url}")
else:
    print("No flight options found.")

print("\n🎉 Done! Your LangGraph-powered travel planning run is complete.\n")
# Out:
# === WEATHER ===
# Temperature ranges between 23.1°C and 27.8°C.
#
# === TOP HOTELS ===
# - Laayoune Central Inn — ⭐ 4.5 — 120.00 per night → https://www.google.com/search?q=Laayoune+Central+Inn+Laayoune+Morocco
# - Oasis View Hotel — ⭐ 4.3 — 190.00 per night → https://www.google.com/search?q=Oasis+View+Hotel+Laayoune+Morocco
# - Hotel Sahara Comfort — ⭐ 4.2 — 150.00 per night → https://www.google.com/search?q=Hotel+Sahara+Comfort+Laayoune+Morocco
# - Atlantic Breeze Hotel — ⭐ 4.1 — 170.00 per night → https://www.google.com/search?q=Atlantic+Breeze+Hotel+Laayoune+Morocco
# - Desert Star Hotel — ⭐ 4.0 — 180.00 per night → https://www.google.com/search?q=Desert+Star+Hotel+Laayoune+Morocco
#
# === TOP FLIGHTS ===
# - Air Arabia Maroc Casablanca → Laayoune — 110.0 → https://flights.example.com/airarabiamaroc-cas-laayoune
# - Royal Air Maroc Casablanca → Laayoune — 120.0 → https://flights.example.com/royalairmaroc-cas-laayoune
# - Atlas Blue Casablanca → Laayoune — 130.0 → https://flights.example.com/atlasblue-cas-laayoune
#
# 🎉 Done! Your LangGraph-powered travel planning run is complete.

# %%
import streamlit as st

# %%
# !streamlit run streamlit_app.py --server.port 8501
